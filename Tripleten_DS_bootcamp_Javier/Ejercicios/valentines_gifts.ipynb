# %%
import pandas as pd 

# Créditos del dataframe: https://www.kaggle.com/aminasalamt
# Pruebas y visualización de ejemplo del df

df = pd.read_csv('C:/Users/becem/Desktop/Entorno_VS_Jupiterlab/Datasets/valentines_day_spending_dataset.csv')

print(df.sample(10))
# Out:
#      user_id  age  gender  ...    plans previous_year_spending sentiment_score
# 117      118   34    Male  ...  Friends                  78.98           -0.73
# 194      195   26  Female  ...  Friends                 146.22            0.06
# 124      125   29  Female  ...     Date                  38.72            0.10
# 159      160   19    Male  ...  Friends                 135.52           -0.42
# 143      144   23    Male  ...    Alone                   5.46            0.51
# 93        94   18    Male  ...  Friends                  79.11            0.97
# 195      196   26  Female  ...     Date                  68.68            0.18
# 42        43   40  Female  ...   Family                 115.66           -0.74
# 83        84   38  Female  ...   Family                  72.08            0.75
# 26        27   31    Male  ...     Date                  83.45            0.71
#
# [10 rows x 12 columns]

# %%
import pandas as pd 

df = pd.read_csv('C:/Users/becem/Desktop/Entorno_VS_Jupiterlab/Datasets/valentines_day_spending_dataset.csv')

# Pruebas y visualización de dimensiones del df

print(df.shape)
# Out:
# (200, 12)
