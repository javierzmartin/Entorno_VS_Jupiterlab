# %% [markdown]
# ##Variables

# %%
print('Hello Word')
# Out:
# Hello Word

# %%
variable_a = 1

# %%
variable_b = 'Hola'

# %%
variable_c = 10.4

# %%
variable_d = True

# %%
primer_nombre = 'Victoria'

# %%
segundoNombre = 'Karol'

# %%
variable_a = 1
variable_b = 'Hola'
variable_c = 10.4

# %%
print(primer_nombre)
# Out:
# Victoria

# %%
segundo_nombre = 'Carlos'
segundo_nombre
# Out:
# 'Carlos'

# %%
var_texto = "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum"

# %%
len(var_texto)
# Out:
# 573

# %%
text =""" this is a new text

dsfasd
asdfasdfas

adsfasdfasd

asdfasdfasdf


asdfasdfasdf
 """

# %%
nombre = 'Juana'
edad = 25
apellido = 'Rojas'
comentarios = 'Cliente Nuevo'

print("El nombre del usuario es: " + nombre + " su edad es: " + str(edad))
# Out:
# El nombre del usuario es: Juana su edad es: 25

# %%
edad_2 = '25'

# %%
#len(edad)

# %%
type(edad)
# Out:
# int

# %%
type(edad_2)
# Out:
# str

# %%
lista = ['Juan',26,'Calero',180.6,True]
print(lista)
# Out:
# ['Juan', 26, 'Calero', 180.6, True]

# %%
lista_anidada = ['Juan',26,'Calero',180.6,True,['Manzana','Durazno','Kiwi']]  #Yo puedo tener listas dentro de listas y estas cuentan como un objeto
print(lista_anidada)
# Out:
# ['Juan', 26, 'Calero', 180.6, True, ['Manzana', 'Durazno', 'Kiwi']]

# %%
#len(lista)

# %%
len(lista_anidada)
# Out:
# 6

# %%
lista_anidada[5]
# Out:
# ['Manzana', 'Durazno', 'Kiwi']

# %%
frutas_lista_anidada = lista_anidada[5]
print(frutas_lista_anidada)
# Out:
# ['Manzana', 'Durazno', 'Kiwi']

# %%
nombre_de_lista = lista_anidada[0]
print(nombre_de_lista)
# Out:
# Juan

# %%
type(frutas_lista_anidada)
# Out:
# list

# %%
lista_anidada.append(['Uvas', 'Arandanos'])

print(lista_anidada)
# Out:
# ['Juan', 26, 'Calero', 180.6, True, ['Manzana', 'Durazno', 'Kiwi'], 'Cafe', 'Cafe', 'Cafe', 2, ['Manzana', 'Durazno', 'Kiwi'], ['Uvas', 'Arandanos']]

# %%
lista_anidada[-3]
# Out:
# 2

# %%
len(lista_anidada)
# Out:
# 12

# %%
lista_anidada.insert(4,'Negro')
print(lista_anidada)
# Out:
# ['Juan', 26, 'Calero', 180.6, 'Negro', 'Negro', True, ['Manzana', 'Durazno', 'Kiwi'], 'Cafe', 'Cafe', 'Cafe', 2, ['Manzana', 'Durazno', 'Kiwi'], ['Uvas', 'Arandanos']]
